# %%
import base64
import sys
import os
from pprint import pprint

# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# from resume_scanner.core.parsing.parsing import parse_resume

# %%
with open("../data/input/resumes/Kevin_resume.pdf", "rb") as file:
    base64_encoded_pdf = base64.b64encode(file.read())

# %%
pprint(parse_resume(base64_encoded_pdf).model_dump())
# Out:
# {'education': {'data': [{'coursework': ['Data Structures & Algorithms',
#                                         'Design & Analysis of Algorithms',
#                                         'Software Engineering',
#                                         'Computer Systems',
#                                         'Machine Learning',
#                                         'Computer Organization',
#                                         'Programming Languages'],
#                          'gpa': 4.0,
#                          'grad_year': 2026,
#                          'honors': ['Dean’s Honor Roll',
#                                     'Engineering Honors',
#                                     'Dean’s Excellence Award Semi-finalist'],
#                          'majors': ['BS in Computer Science'],
#                          'minors': ['Statistics', 'Math'],
#                          'name': 'Texas A&M University'}]},
#  'experience': {'roles': [{'company': 'Sandia National Laboratories',
#                            'contributions': ['Developed 3-stage knowledge '
#                                              'graph generation pipeline with '
#                                              'LLM microservices based on '
#                                              'Graphusion paper',
#                                              'Aligned knowledge graph '
#                                              'generation to annotator '
#                                              'guidelines via extraction of '
#                                              'seed topics with BERTopic',
#                                              'Achieved 100% JSON-compliant LLM '
#                                              'outputs via prompt engineering '
#                                              'and structured outputs',
#                                              'Packaged KG generation workflow '
#                                              'into object-oriented Python '
#                                              'module used by 30 developers'],
#                            'end_date': '12-2024',
#                            'role': 'AI/ML Intern',
#                            'skills': ['Knowledge Graphs',
#                                       'LLM Microservices',
#                                       'BERTopic',
#                                       'JSON Compliance',
#                                       'Python'],
#                            'start_date': '08-2024'},
#                           {'company': 'Sandia National Laboratories',
#                            'contributions': ['Redesigned 30 year old Java data '
#                                              'analysis system architecture, '
#                                              'cutting developer onboarding '
#                                              'time by 3 weeks',
#                                              'Used MATLAB profiler to find '
#                                              'bottleneck in data preprocessing '
#                                              'script, leading to 90% execution '
#                                              'time reduction',
#                                              'Designed Java class to interface '
#                                              'with Javalin REST API, enabling '
#                                              'multithreaded network '
#                                              'communication',
#                                              'Implemented test-driven '
#                                              'development methodology via '
#                                              'integration testing in Jenkins '
#                                              'CI/CD pipeline'],
#                            'end_date': '08-2024',
#                            'role': 'Software Engineering Intern',
#                            'skills': ['Java',
#                                       'MATLAB',
#                                       'Javalin REST API',
#                                       'Multithreading',
#                                       'Jenkins CI/CD',
#                                       'Test-Driven Development'],
#                            'start_date': '05-2024'},
#                           {'company': 'Vertical Automation and Information '
#                                       'Technology',
#                            'contributions': ['Built CRM system with ASP.NET '
#                                              'MVC serving 10 users, reducing '
#                                              'administrative overhead by 50%',
#                                              'Optimized MySQL database '
#                                              'performance by eliminating 1,000 '
#                                              'duplicate records, improving '
#                                              'query speed by 10%',
#                                              'Designed scalable SQL database '
#                                              'schema and presented it in human '
#                                              'language to non-technical '
#                                              'stakeholders',
#                                              'Created role-based authorization '
#                                              'system with Entity Framework to '
#                                              'facilitate project management'],
#                            'end_date': '08-2022',
#                            'role': 'Full Stack Developer Intern',
#                            'skills': ['ASP.NET MVC',
#                                       'MySQL',
#                                       'SQL Database Design',
#                                       'Entity Framework',
#                                       'Role-Based Authorization'],
#                            'start_date': '06-2022'},
#                           {'company': 'Vertical Automation and Information '
#                                       'Technology',
#                            'contributions': ['Built CRM system with ASP.NET '
#                                              'MVC serving 10 users, reducing '
#                                              'administrative overhead by 50%',
#                                              'Optimized MySQL database '
#                                              'performance by eliminating 1,000 '
#                                              'duplicate records, improving '
#                                              'query speed by 10%',
#                                              'Designed scalable SQL database '
#                                              'schema and presented it in human '
#                                              'language to non-technical '
#                                              'stakeholders',
#                                              'Created role-based authorization '
#                                              'system with Entity Framework to '
#                                              'facilitate project management'],
#                            'end_date': '08-2023',
#                            'role': 'Full Stack Developer Intern',
#                            'skills': ['ASP.NET MVC',
#                                       'MySQL',
#                                       'SQL Database Design',
#                                       'Entity Framework',
#                                       'Role-Based Authorization'],
#                            'start_date': '05-2023'}],
#                 'yoe': 1.0},
#  'leadership': {'contributions': ['Leading data structures & algorithms '
#                                   'recitations for 60 students semiweekly',
#                                   'Helping 15+ students weekly in debugging '
#                                   'C++ STL data structure implementations '
#                                   '(vector, list, hashmap)',
#                                   'Teaching CS fundamentals including '
#                                   'asymptotic analysis, trees, graph '
#                                   'algorithms, sorting, and recursion'],
#                 'org': 'Texas A&M University',
#                 'role': 'Undergraduate Teaching Assistant'},
#  'projects': {'data': [{'contributions': ['Generated recommendations with '
#                                           'OpenAI Structured Outputs to ensure '
#                                           'valid JSON generations',
#                                           'Devised retrieval augmented '
#                                           'generation logic to supplement LLM '
#                                           'outputs with credit card database '
#                                           'queries'],
#                         'name': 'Credit Card Recommender (Best Financial Hack)',
#                         'skills': ['Python',
#                                    'Jupyter',
#                                    'Flask',
#                                    'LangChain',
#                                    'OpenAI',
#                                    'JSON']},
#                        {'contributions': ['Designed modular React components '
#                                           'and managed application state with '
#                                           'React hooks',
#                                           'Orchestrated integration of Google '
#                                           'OAuth API with employee database to '
#                                           'manage authentication',
#                                           'Implemented JDBC backend to map '
#                                           'PostgreSQL entries to Java data '
#                                           'transfer objects in under one '
#                                           'second',
#                                           'Reviewed 60+ GitHub pull requests '
#                                           'as lead backend developer, '
#                                           'resulting in 80% reduction in code '
#                                           'smells'],
#                         'name': 'Point of Sales System',
#                         'skills': ['React',
#                                    'TypeScript',
#                                    'Spring Boot',
#                                    'PostgreSQL',
#                                    'Git',
#                                    'Google OAuth API',
#                                    'JDBC',
#                                    'Java',
#                                    'data transfer objects']}]},
#  'research': None,
#  'skills': {'data': ['Java',
#                      'Python',
#                      'TypeScript',
#                      'HTML',
#                      'CSS',
#                      'C/C++',
#                      'C#',
#                      'SQL',
#                      'MATLAB',
#                      'Bash',
#                      'React',
#                      'Flask',
#                      'JUnit',
#                      'ASP.NET',
#                      'Entity Framework',
#                      'Spring Boot',
#                      'JDBC',
#                      'Numpy',
#                      'Pandas',
#                      'Matplotlib',
#                      'LangChain',
#                      'OpenAI',
#                      'Pydantic',
#                      'Linux',
#                      'Git',
#                      'Anaconda',
#                      'Jupyter',
#                      'Azure DevOps',
#                      'Jenkins',
#                      'Vim',
#                      'PostgreSQL',
#                      'MySQL',
#                      'Neo4J']}}

# %%
with open("../data/input/resumes/Kevin_resume_img.pdf", "rb") as file:
    encoded_pdf_img = base64.b64encode(file.read())

# %%
pprint(parse_resume(encoded_pdf_img).model_dump())
# Out:
# {'education': {'data': [{'coursework': ['Data Structures & Algorithms',
#                                         'Software Engineering',
#                                         'Computer Systems',
#                                         'Discrete Math',
#                                         'Linear Algebra'],
#                          'gpa': 4.0,
#                          'grad_year': 2026,
#                          'honors': ['Dean’s Honor Roll',
#                                     'Engineering Honors (EH)',
#                                     'Dean’s Excellence Award Semi-finalist'],
#                          'majors': ['BS in Computer Science'],
#                          'minors': ['Statistics', 'Math'],
#                          'name': 'Texas A&M University'}]},
#  'experience': {'roles': [{'company': 'Sandia National Laboratories',
#                            'contributions': ['Developed knowledge graph (KG) '
#                                              'generation pipeline with '
#                                              'internal LLM microservices',
#                                              'Extracted 30+ domain-specific '
#                                              'seed topics from text corpus '
#                                              'with BERTopic',
#                                              'Achieved 100% schema-compliant '
#                                              'LLM outputs via prompt '
#                                              'engineering and '
#                                              'grammar-constrained decoding',
#                                              'Packaged KG generation logic '
#                                              'into reusable, object-oriented '
#                                              'Python modules'],
#                            'end_date': '12-2024',
#                            'role': 'AI/ML Intern',
#                            'skills': ['knowledge graph generation',
#                                       'LLM microservices',
#                                       'BERTopic',
#                                       'prompt engineering',
#                                       'Python'],
#                            'start_date': '08-2024'},
#                           {'company': 'Sandia National Laboratories',
#                            'contributions': ['Redesigned 30 year old Java data '
#                                              'analysis suite architecture',
#                                              'Used MATLAB profiler to find '
#                                              'bottleneck in data preprocessing '
#                                              'script',
#                                              'Built Java class to interface '
#                                              'with Javalin REST API',
#                                              'Reduced logic errors by 50% via '
#                                              'integration and regression '
#                                              'testing in Jenkins CI/CD '
#                                              'pipeline'],
#                            'end_date': '08-2024',
#                            'role': 'Software Engineering Intern',
#                            'skills': ['Java',
#                                       'MATLAB',
#                                       'Javalin REST API',
#                                       'Jenkins CI/CD',
#                                       'integration testing'],
#                            'start_date': '05-2024'},
#                           {'company': 'Texas A&M University',
#                            'contributions': ['Leading data structures & '
#                                              'algorithms recitations for 60 '
#                                              'students',
#                                              'Mentoring 15+ students weekly in '
#                                              'C++ assignments',
#                                              'Teaching students core CS '
#                                              'concepts including vectors, '
#                                              'trees, graphs, sorting '
#                                              'algorithms, and recursion'],
#                            'end_date': 'Present',
#                            'role': 'Undergraduate Teaching Assistant',
#                            'skills': ['C++',
#                                       'data structures',
#                                       'algorithms',
#                                       'mentoring',
#                                       'teaching'],
#                            'start_date': '01-2024'},
#                           {'company': 'Vertical Automation and Information '
#                                       'Technology',
#                            'contributions': ['Built CRM system with ASP.NET '
#                                              'MVC serving 10 users',
#                                              'Optimized MySQL database '
#                                              'performance by eliminating 1,000 '
#                                              'duplicate records',
#                                              'Designed scalable SQL database '
#                                              'architecture',
#                                              'Created role-based authorization '
#                                              'system with Entity Framework'],
#                            'end_date': '08-2022',
#                            'role': 'Full Stack Developer Intern',
#                            'skills': ['ASP.NET MVC',
#                                       'MySQL',
#                                       'SQL database architecture',
#                                       'Entity Framework'],
#                            'start_date': '06-2022'},
#                           {'company': 'Vertical Automation and Information '
#                                       'Technology',
#                            'contributions': ['Built CRM system with ASP.NET '
#                                              'MVC serving 10 users',
#                                              'Optimized MySQL database '
#                                              'performance by eliminating 1,000 '
#                                              'duplicate records',
#                                              'Designed scalable SQL database '
#                                              'architecture',
#                                              'Created role-based authorization '
#                                              'system with Entity Framework'],
#                            'end_date': '08-2023',
#                            'role': 'Full Stack Developer Intern',
#                            'skills': ['ASP.NET MVC',
#                                       'MySQL',
#                                       'SQL database architecture',
#                                       'Entity Framework'],
#                            'start_date': '05-2023'}],
#                 'yoe': 1.0},
#  'leadership': None,
#  'projects': {'data': [{'contributions': ['Developed LLM-based credit card '
#                                           'recommendation system at 24-hour '
#                                           'hackathon, competing against 14 '
#                                           'teams',
#                                           'Devised chain-of-thought (CoT) '
#                                           'recommendation prompt that takes '
#                                           'user spending habits into account',
#                                           'Augmented recommendations with '
#                                           'self-curated JSON database '
#                                           'containing statistics on 50 popular '
#                                           'credit cards'],
#                         'name': 'Credit Card Recommender',
#                         'skills': ['Python',
#                                    'Jupyter',
#                                    'Flask',
#                                    'React',
#                                    'LangChain',
#                                    'LLM-based systems',
#                                    'JSON database management']},
#                        {'contributions': ['Designed modular React components '
#                                           'and managed application state with '
#                                           'React hooks (useState, useContext)',
#                                           'Orchestrated integration of Google '
#                                           'OAuth API to manage '
#                                           'authentication/authorization',
#                                           'Implemented JDBC backend to query '
#                                           'PostgreSQL database and map results '
#                                           'to Java data transfer objects',
#                                           'Reviewed 60+ GitHub pull requests, '
#                                           'leading to 80% reduction in code '
#                                           'smells'],
#                         'name': 'Point of Sales System',
#                         'skills': ['React',
#                                    'TypeScript',
#                                    'Java',
#                                    'Spring Boot',
#                                    'PostgreSQL',
#                                    'JDBC',
#                                    'Git',
#                                    'OAuth API integration',
#                                    'Code review']}]},
#  'research': None,
#  'skills': {'data': ['Java',
#                      'Python',
#                      'C/C++',
#                      'TypeScript',
#                      'JavaScript',
#                      'C#',
#                      'SQL',
#                      'HTML',
#                      'CSS',
#                      'MATLAB',
#                      'Bash',
#                      'React',
#                      'Bootstrap',
#                      'Flask',
#                      'JUnit',
#                      'ASP.NET',
#                      'Entity Framework',
#                      'Spring Boot',
#                      'Numpy',
#                      'Pandas',
#                      'Matplotlib',
#                      'LangChain',
#                      'OpenAI',
#                      'Pydantic',
#                      'TensorFlow',
#                      'Linux',
#                      'Git',
#                      'GitHub',
#                      'Gerrit',
#                      'Anaconda',
#                      'Jupyter',
#                      'Azure DevOps',
#                      'Jenkins',
#                      'Vim',
#                      'Docker',
#                      'PostgreSQL',
#                      'MySQL',
#                      'Neo4J']}}

# %%
with open("../data/input/resumes/output.txt", "r") as file:
    b64_str = file.read()
    
with open("../data/input/resumes/output.pdf", "wb") as file:
    file.write(base64.b64decode(b64_str))
